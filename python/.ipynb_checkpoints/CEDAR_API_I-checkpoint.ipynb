# %% [markdown]
# # CEDAR Query API - Example Search Scenarios and Queries
#
# The Cancer Epitope Database and Analysis Resource (CEDAR) API (Application Programming Interface) enables users to perform queries and retrieve CEDAR data programmatically within their preferred environment. This Python Notebook Series illustrates basic usage examples of the CEDAR API using Python.
#
# The CEDAR API is built on a PostgREST platform, providing transparent access to the tables on the backend. For more information on the expressive syntax of PostgREST, refer to this [document](https://postgrest.org/en/stable/api.html#). The CEDAR data can be queried through search and export endpoints described in the [CEDAR API documentation](https://discuss.iedb.org/t/application-programming-interface-api/220) and the interactive [Swagger documentation](https://cedar-api.iedb.org/docs/swagger/).
#
# These example search scenarios and queries are derived from this [Book Chapter](https://doi.org/10.1007/978-1-0716-4566-6_3), which describes how to perform different queries to the [CEDAR homepage](https://cedar.iedb.org). This notebook reproduces the same queries using the CEDAR API.

# %% [markdown]
# ## Research scenario I
#
# For a literature review, we want to retrieve all the references that contain assays testing epitopes from the antigen “Prostate-specific antigen”.

# %% [markdown]
# ### Approach
#
# To retrieve this data, we will execute the following steps:
# 1. **Search references** - Identify the articles that report assays of the target antigen
# 3. **Retrieve complete reference data** - Obtain full bibliographic information
#
# Each step requires a request to a different interconnected endpoint. For more information, refer to the [PostgREST resource embedding documentation](https://docs.postgrest.org/en/v12/references/api/resource_embedding.html#resource-embedding).

# %% [markdown]
# ### Setup
#
# First, import the required modules and define a function to make CEDAR API requests. This function takes the endpoint, the search parameters, and the base URI (Unified Resource Identifier) as inputs. Based on these, it constructs the URL (Unified Resource Locator) to interact with the data and resources specified. Then, it performs the API request.
# Since the API has a maximum limit of 10,000 rows per request, the function iterates through results, retrieving data in chunks.
# Finally, it parses the response and returns a pandas DataFrame. For more information, refer to [pandas documentation](https://pandas.pydata.org/).

# %%
import os
import requests
import pandas as pd
import io
import time

pd.set_option('display.max_columns', 100)

def API_query(endpoint, query_params, base_uri='https://cedar-api.iedb.org/'):
    """
    Execute a query against the CEDAR API with pagination support.

    Parameters:
    -----------
    endpoint : str
        The API endpoint to query
    query_params : dict
        Dictionary of query parameters
    base_uri : str
        Base URI for the CEDAR API

    Returns:
    --------
    pd.DataFrame
        Combined results from all paginated requests
    """

    url = os.path.join(base_uri, endpoint)
    df = pd.DataFrame()

    # set the offset to 0
    query_params['offset'] = 0

    # loop through the pages of results
    # API only allows pulling 10,000 entries at a time
    while(True):
        print('Fetching offset: %i' % query_params['offset'])
        r = requests.get(
            url,
            params=query_params,
            headers={'accept': 'text/csv', 'Prefer': 'count=exact'}
        )

        try:
            # Parse CSV response and append to existing DataFrame
            df = pd.concat([df, pd.read_csv(io.StringIO(r.content.decode('utf-8')))])
            query_params['offset'] += 10000
        except pd.errors.EmptyDataError:
            # No more data available
            break

        # Rate limiting: pause between requests to not overload the server
        time.sleep(1)

    return df

# %% [markdown]
# ### Step 1: Search Epitopes
#
# In this example, we are searching for **references** that tested a specific antigen.
#
# The CEDAR API provides two types of endpoints, the search and export. The search endpoints contain fields with information that facilitate to programatically identify and/or filter the data of interest, while the export endpoints organize the data in a user-friendly format, matching the structure and naming conventions of the custom exports on the CEDAR website.
#
# To perform our query, we will first use the `reference_search` endpoint. Let's examine its structure and available fields.

# %%
cedar_url='https://cedar-api.iedb.org/'
endpoint='reference_search'

table = pd.json_normalize(requests.get(os.path.join(cedar_url, endpoint + '?limit=3')).json())
display(table)
# Out:
#    reference_id           reference_iri e_modifications  \
# 0       1028287  IEDB_REFERENCE:1028287            None
# 1       1032584  IEDB_REFERENCE:1032584            None
# 2       1025245  IEDB_REFERENCE:1025245            None
#
#   linear_sequence_lengths                               qualitative_measures  \
# 0          [8, 9, 10, 11]  [Negative, Positive-High, Positive-Intermediat...
# 1                     [9]            [Positive, Positive-High, Positive-Low]
# 2                     [9]                                         [Positive]
#
#            journal_name antibody_isotypes  direct_ex_vivo_bool submission_ids  \
# 0                  None              None                    0      [1000635]
# 1  Asian Pac J Trop Med              None                    0           None
# 2             Gene Ther              None                    0           None
#
#              submission_iris pdb_ids  \
# 0  [IEDB_SUBMISSION:1000635]    None
# 1                       None    None
# 2                       None    None
#
#                                       iedb_assay_ids  \
# 0  [2147395, 2147396, 2147397, 2147398, 2147399, ...
# 1  [22756276, 22756277, 22756278, 22756279, 22756...
# 2               [1962331, 1962332, 1962333, 1962334]
#
#                                      iedb_assay_iris  \
# 0  [IEDB_ASSAY:2147395, IEDB_ASSAY:2147396, IEDB_...
# 1  [IEDB_ASSAY:22756276, IEDB_ASSAY:22756277, IED...
# 2  [IEDB_ASSAY:1962331, IEDB_ASSAY:1962332, IEDB_...
#
#                                        structure_ids  \
# 0  [317, 1913, 1964, 2114, 2131, 2760, 2800, 3043...
# 1  [487525, 735828, 1352931, 1741383, 1747538, 17...
# 2                                      [6568, 74886]
#
#                                       structure_iris   structure_types  \
# 0  [IEDB_EPITOPE:10088, IEDB_EPITOPE:108723, IEDB...  [Linear peptide]
# 1  [IEDB_EPITOPE:1352931, IEDB_EPITOPE:1741383, I...  [Linear peptide]
# 2            [IEDB_EPITOPE:6568, IEDB_EPITOPE:74886]  [Linear peptide]
#
#                                     linear_sequences mhc_classes  \
# 0  [AADFPGIAR, AAMVLLLRK, AANEIRISK, AAYVLPLHR, A...         [I]
# 1  [ELFDSLFPV, FIDKKVLKV, FLAELAYDL, FLIIQNAAV, F...         [I]
# 2                             [CLGGLLTMV, YLQQNWWTL]         [I]
#
#   mhc_allele_resolutions                         parent_source_antigen_iris  \
# 0              [2 chain]  [taxon_protein:197-other, taxon_protein:28901-...
# 1              [2 chain]                                   [UNIPROT:P51654]
# 2              [2 chain]                   [UNIPROT:P03230, UNIPROT:P13285]
#
#                          parent_source_antigen_names  \
# 0  [1,4-dihydroxy-2-naphthoyl-CoA synthase (UniPr...
# 1                      [Glypican-3 (UniProt:P51654)]
# 2  [Latent membrane protein 1 (UniProt:P03230), L...
#
#                parent_source_antigen_source_org_iris  \
# 0  [NCBITaxon:10090, NCBITaxon:10245, NCBITaxon:1...
# 1                                   [NCBITaxon:9606]
# 2                                  [NCBITaxon:10376]
#
#               parent_source_antigen_source_org_names e_related_object_types  \
# 0  [Acinetobacter baumannii, Actinobacillus pleur...                   None
# 1                             [Homo sapiens (human)]                   None
# 2         [Human herpesvirus 4 (Epstein Barr virus)]                   None
#
#                                            tcell_ids  \
# 0                                               None
# 1  [22756283, 22756285, 22756286, 22756287, 22756...
# 2               [1962331, 1962332, 1962333, 1962334]
#
#                                           tcell_iris bcell_ids bcell_iris  \
# 0                                               None      None       None
# 1  [IEDB_ASSAY:22756283, IEDB_ASSAY:22756285, IED...      None       None
# 2  [IEDB_ASSAY:1962331, IEDB_ASSAY:1962332, IEDB_...      None       None
#
#                                          elution_ids  \
# 0  [2147395, 2147396, 2147397, 2147398, 2147399, ...
# 1  [22756276, 22756277, 22756278, 22756279, 22756...
# 2                                               None
#
#                                         elution_iris receptor_ids  \
# 0  [IEDB_ASSAY:2147395, IEDB_ASSAY:2147396, IEDB_...         None
# 1  [IEDB_ASSAY:22756276, IEDB_ASSAY:22756277, IED...         None
# 2                                               None         None
#
#   receptor_group_ids tcr_receptor_group_ids bcr_receptor_group_ids  \
# 0               None                   None                   None
# 1               None                   None                   None
# 2               None                   None                   None
#
#   receptor_group_iris tcr_receptor_group_iris bcr_receptor_group_iris  \
# 0                None                    None                    None
# 1                None                    None                    None
# 2                None                    None                    None
#
#   receptor_types receptor_names receptor_chain1_types receptor_chain2_types  \
# 0           None           None                  None                  None
# 1           None           None                  None                  None
# 2           None           None                  None                  None
#
#   receptor_chain1_cdr1_seqs receptor_chain1_cdr2_seqs  \
# 0                      None                      None
# 1                      None                      None
# 2                      None                      None
#
#   receptor_chain1_cdr3_seqs receptor_chain1_full_seqs  \
# 0                      None                      None
# 1                      None                      None
# 2                      None                      None
#
#   receptor_chain2_cdr1_seqs receptor_chain2_cdr2_seqs  \
# 0                      None                      None
# 1                      None                      None
# 2                      None                      None
#
#   receptor_chain2_cdr3_seqs receptor_chain2_full_seqs  \
# 0                      None                      None
# 1                      None                      None
# 2                      None                      None
#
#                                      reference_title reference_title2  \
# 0  Large scale analysis of peptide - HLA-I stability             None
# 1  Glypican-3-specific cytotoxic T lymphocytes in...             None
# 2  Generating CTLs against the subdominant EBV LM...             None
#
#                                     reference_author reference_author2  \
# 0  Michael Rasmussen M.Sc; Mikkel Nors Harndahl P...              None
# 1  Jiang-Zheng Zeng; Yu Liu; Fen Huang; Zhi-Hui H...              None
# 2  B Hong; G Peng; L Berry; S Gottschalk; J U Jun...              None
#
#   reference_date reference_date2 pubmed_id  \
# 0           2014            None      None
# 1           2017            None  29203107
# 2           2012            None  22052242
#
#                                mhc_allele_iri_search mhc_allele_iris  \
# 0  [GO:0032991, GO:0042611, MRO:0000011, MRO:0001...   [MRO:0001029]
# 1  [GO:0032991, GO:0042611, MRO:0000011, MRO:0001...   [MRO:0001007]
# 2  [GO:0032991, GO:0042611, MRO:0000011, MRO:0001...   [MRO:0001007]
#
#   mhc_allele_names                                   assay_iri_search  \
# 0    [HLA-A*11:01]  [OBI:0001553, OBI:0001586, OBI:0001990, OBI:00...
# 1    [HLA-A*02:01]  [OBI:0001414, OBI:0001553, OBI:0001559, OBI:00...
# 2    [HLA-A*02:01]  [OBI:0001414, OBI:0002055, OBI:0003128, OBI:11...
#
#                                 assay_iris  \
# 0                            [OBI:0001586]
# 1  [OBI:0001559, OBI:0002062, OBI:1110059]
# 2               [OBI:1110059, OBI:1110179]
#
#                                          assay_names  \
# 0  [half life|purified MHC/direct/radioactivity|min]
# 1  [cytotoxicity|in vitro assay, half life|cellul...
# 2  [IFNg release|ELISPOT, qualitative binding|mul...
#
#   epitope_structures_defined  \
# 0            [Exact Epitope]
# 1            [Exact Epitope]
# 2            [Exact Epitope]
#
#                             host_organism_iri_search host_organism_iris  \
# 0  [NCBITaxon:314295, NCBITaxon:40674, NCBITaxon:...   [NCBITaxon:9606]
# 1  [NCBITaxon:314295, NCBITaxon:40674, NCBITaxon:...   [NCBITaxon:9606]
# 2  [NCBITaxon:314295, NCBITaxon:40674, NCBITaxon:...   [NCBITaxon:9606]
#
#       host_organism_names                         source_organism_iri_search  \
# 0  [Homo sapiens (human)]  [NCBITaxon:1, NCBITaxon:100226, NCBITaxon:1009...
# 1  [Homo sapiens (human)]  [NCBITaxon:1, NCBITaxon:2759, NCBITaxon:314295...
# 2  [Homo sapiens (human)]  [NCBITaxon:1, NCBITaxon:10239, NCBITaxon:10292...
#
#                                 source_organism_iris  \
# 0  [NCBITaxon:100226, NCBITaxon:10090, NCBITaxon:...
# 1                                   [NCBITaxon:9606]
# 2                                  [NCBITaxon:10376]
#
#                                source_organism_names  \
# 0  [Acinetobacter baumannii AYE (Acinetobacter ba...
# 1                             [Homo sapiens (human)]
# 2         [Human herpesvirus 4 (Epstein Barr virus)]
#
#                disease_iri_search     disease_iris disease_names  \
# 0                            None             None          None
# 1  [ONTIE:0003423, ONTIE:0003543]  [ONTIE:0003423]     [healthy]
# 2  [ONTIE:0003423, ONTIE:0003543]  [ONTIE:0003423]     [healthy]
#
#                     parent_source_antigen_iri_search  \
# 0  [PR:000000001, taxon_protein:10002039, taxon_p...
# 1  [PR:000000001, taxon_protein:2759, taxon_prote...
# 2  [PR:000000001, taxon_protein:10002039, taxon_p...
#
#   non_peptidic_molecule_iri_search non_peptidic_molecule_iris  \
# 0                             None                       None
# 1                             None                       None
# 2                             None                       None
#
#   non_peptidic_molecule_names r_object_source_molecule_iri_search  \
# 0                        None                                None
# 1                        None                                None
# 2                        None                                None
#
#   r_object_source_molecule_iris r_object_source_molecule_names  \
# 0                          None                           None
# 1                          None                           None
# 2                          None                           None
#
#   r_object_source_organism_iri_search r_object_source_organism_iris  \
# 0                                None                          None
# 1                                None                          None
# 2                                None                          None
#
#   r_object_source_organism_names mhc_allele_evidences chebi_ids  \
# 0                           None                 None      None
# 1                           None  [MHC binding assay]      None
# 2                           None    [Cited reference]      None
#
#                               structure_descriptions  \
# 0  [AADFPGIAR, AAMVLLLRK, AANEIRISK, AAYVLPLHR, A...
# 1  [ELFDSLFPV, FIDKKVLKV, FLAELAYDL, FLIIQNAAV, F...
# 2                             [CLGGLLTMV, YLQQNWWTL]
#
#                              curated_source_antigens  neoantigen_bool  \
# 0  [{'accession': '0704313A', 'name': 'neuraminid...                0
# 1  [{'accession': 'P51654.1', 'name': 'Glypican-3...                0
# 2  [{'accession': 'ABM45855.1', 'name': 'latent m...                0
#
#    viral_antigen_bool  germline_antigen_bool  other_antigen_bool  \
# 0                   1                      1                   1
# 1                   0                      1                   0
# 2                   1                      0                   0
#
#   disease_stages  naturally_occuring_disease_bool  \
# 0           None                                0
# 1           None                                0
# 2           None                                0
#
#    animal_model_of_cancer_bool  all_vaccination_bool  \
# 0                            0                     0
# 1                            0                     0
# 2                            0                     0
#
#    prophylactic_vaccination_bool  therapeutic_vaccination_bool mutations
# 0                              0                             0      None
# 1                              0                             0      None
# 2                              0                             0      None

# %% [markdown]
# Next, we define the search parameters, which consist of three components:
#
# - The **query filters:**  that we want to impose on the data.
#
#   Here, we are interested in epitopes derived from a specific source antigen. It is possible to filter by the protein name using the `parent_source_antigen_name` field (e.g. `ilike.*Prostate-specific antigen*`). However, for more efficient and exact results, it is preferred to search by a protein identifier using the `parent_source_antigen_iri_search` field. This field contains a tree of IRIs (Internationalized Resource Identifiers) that point to external resources such as [UniProt](www.uniprot.org), allowing users to filter the data using stable and unique identifiers. The UniProt ID of the Prostate-specific antigen is [P07288](https://www.uniprot.org/uniprotkb/P07288/entry).
#
#
#   We utilize operators in the query parameters, such as `ilike` and `ov`. These operators allow us to perform flexible queries and refine the search. For more information on the operators' syntax, refer to this [documentation](https://docs.postgrest.org/en/v12/references/api/tables_views.html#operators).
#
# - The **pagination parameters** required to retrieve the results in chunks. The order parameter is a field used to sort and paginate the data so that each retrieved chunk contains different consecutive rows. The offset parameter indicates the index of the first element of each data chunk.
# - The final **column selection**. In this case, we will keep the `reference_id` field. It will be used for subsequent queries to other endpoints.

# %%
cedar_url='https://cedar-api.iedb.org/'
endpoint='reference_search'

search_params={
    # Query filters
    'parent_source_antigen_iri_search':'ov.{UNIPROT:P07288}',

    # Pagination
    'order': 'reference_id',
    'offset': 0,

    # Column selection
    'select': 'reference_id',
}

# Execute reference search
reference_df = API_query(endpoint, search_params)

print(f"Retrieved {len(reference_df)} reference records")
reference_df.head()
# Out:
# Fetching offset: 0
# Fetching offset: 10000
# Retrieved 83 reference records
#    reference_id
# 0           305
# 1        200059
# 2        200060
# 3        200080
# 4        315269

# %% [markdown]
# ### Step 2: Retrieve Complete Reference Data
#
# With the reference IDs, we query the `reference_export` endpoint. This table contains the complete bibliographic information associated to the publications. To perform this query, we format the reference IDs, include them in the search parameters, and perform the API request.

# %%
endpoint='reference_export'

# Format unique reference IDs
reference_ids = ','.join(map(str, set(reference_df['reference_id'].tolist())))

search_params = {
    # Query filter
    'reference_id': f'in.({reference_ids})',

    # Pagination
    'order': 'reference_id',
    'offset': 0,
}

# Execute final query
references_df = API_query(endpoint, search_params)

print(f"Retrieved {len(references_df)} reference records")
references_df.head()
# Out:
# Fetching offset: 0
# Fetching offset: 10000
# Retrieved 83 reference records
#    reference_id                  reference_id__cedar_iri reference__type  \
# 0           305     https://cedar.iedb.org/reference/305      Literature
# 1        200059  https://cedar.iedb.org/reference/200059      Literature
# 2        200060  https://cedar.iedb.org/reference/200060      Literature
# 3        200080  https://cedar.iedb.org/reference/200080      Literature
# 4        315269  https://cedar.iedb.org/reference/315269      Literature
#
#    reference__pmid  reference__submission_id reference__alternate_iris  \
# 0       15651071.0                       NaN                       NaN
# 1        8871647.0                       NaN                       NaN
# 2        8882405.0                       NaN                       NaN
# 3        9438205.0                       NaN                       NaN
# 4        9743387.0                       NaN                       NaN
#
#                                   reference__authors  \
# 0  Maxim Pavlenko; Christoph Leder; Anna-Karin Ro...
# 1  J Sidney; S Southwood; M F del Guercio; H M Gr...
# 2  J Sidney; H M Grey; S Southwood; E Celis; P A ...
# 3  J Sidney; M F del Guercio; S Southwood; G Herm...
# 4  P Correale; K Walmsley; S Zaremba; M Zhu; J Sc...
#
#                               reference__journal  reference__date  \
# 0                                   The Prostate             2005
# 1  Journal of immunology (Baltimore, Md. : 1950)             1996
# 2                               Human immunology             1996
# 3                               Human immunology             1997
# 4  Journal of immunology (Baltimore, Md. : 1950)             1998
#
#                                     reference__title
# 0  Identification of an immunodominant H-2D(b)-re...
# 1  Specificity and degeneracy in peptide binding ...
# 2  Definition of an HLA-A3-like supermotif demons...
# 3  The HLA-A*0207 peptide binding repertoire is l...
# 4  Generation of human cytolytic T lymphocyte lin...

# %% [markdown]
# ### Results
#
# The retrieved data contains all publications reporting T cell assays of epitopes from the Prostate-specific antigen. This programmatic approach demonstrates the CEDAR API's capability for automated data retrieval and analysis.

# %% [markdown]
# ## References
#
# Koşaloğlu-Yalçın, Z. et al. (2025) *Using the Cancer Epitope Database and Analysis Resource (CEDAR)*. Alexander Krasnitz and Pascal Belleau (Eds.), *Cancer Bioinformatics, Methods in Molecular Biology*, vol. 2932. [https://doi.org/10.1007/978-1-0716-4566-6_3 ](https://doi.org/10.1007/978-1-0716-4566-6_3)
#
# Koşaloğlu-Yalçın, Z. et al. (2023) *The cancer epitope database and analysis resource (CEDAR).* Nucleic acids research 51, no. D1 (2023): D845-D852. [https://doi.org/10.1093/nar/gkac902 ](https://doi.org/10.1093/nar/gkac902)
